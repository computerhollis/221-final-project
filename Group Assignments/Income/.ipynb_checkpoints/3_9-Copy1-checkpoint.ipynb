# %% [markdown]
# # Mapping income, housing cost, and arrest data in LA County.
# ## For this part of the project, I am interested in mapping both income and hosuing cost disparities in LA County and spatially relating this to the Million Dollar Hoods data, which shows that South Central and Downtown LA are the two most policed areas in the county. I will be using census data and the LAPD's arrest data to explore the spatial relation between income, housing costs, and arrests.
# ### One note on housing costs: for the purposes of this project, I am interested in housing costs as a percentage of median household income in each census tract.

# %%
import os
os.chdir('/home/jovyan/221-final-project/Group Assignments/Income')

# %%
# !pip install RISE
# Out:
# Collecting RISE
#   Using cached rise-5.7.1-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: notebook>=6.0 in /opt/conda/lib/python3.11/site-packages (from RISE) (7.2.2)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /opt/conda/lib/python3.11/site-packages (from notebook>=6.0->RISE) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /opt/conda/lib/python3.11/site-packages (from notebook>=6.0->RISE) (2.27.3)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in /opt/conda/lib/python3.11/site-packages (from notebook>=6.0->RISE) (4.2.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /opt/conda/lib/python3.11/site-packages (from notebook>=6.0->RISE) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in /opt/conda/lib/python3.11/site-packages (from notebook>=6.0->RISE) (6.4.1)
# Requirement already satisfied: anyio>=3.1.0 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (4.4.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (23.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (3.1.4)
# Requirement already satisfied: jupyter-client>=7.4.4 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (8.6.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (7.16.4)
# Requirement already satisfied: nbformat>=5.3.0 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (7.7.0)
# Requirement already satisfied: packaging>=22.0 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (24.1)
# Requirement already satisfied: prometheus-client>=0.9 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (0.20.0)
# Requirement already satisfied: pyzmq>=24 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (26.2.0)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (0.18.1)
# Requirement already satisfied: traitlets>=5.6.0 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (5.14.3)
# Requirement already satisfied: websocket-client>=1.7 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=6.0->RISE) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /opt/conda/lib/python3.11/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=6.0->RISE) (0.27.2)
# Requirement already satisfied: ipykernel>=6.5.0 in /opt/conda/lib/python3.11/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=6.0->RISE) (6.29.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=6.0->RISE) (2.2.5)
# Requirement already satisfied: setuptools>=40.1.0 in /opt/conda/lib/python3.11/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=6.0->RISE) (73.0.1)
# Requirement already satisfied: babel>=2.10 in /opt/conda/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->RISE) (2.14.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/conda/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->RISE) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/conda/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->RISE) (4.23.0)
# Requirement already satisfied: requests>=2.31 in /opt/conda/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->RISE) (2.32.3)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (3.8)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /opt/conda/lib/python3.11/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (21.2.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->RISE) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.11/site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->RISE) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->RISE) (0.14.0)
# Requirement already satisfied: comm>=0.1.1 in /opt/conda/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->RISE) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/conda/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->RISE) (1.8.5)
# Requirement already satisfied: ipython>=7.23.1 in /opt/conda/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->RISE) (8.27.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/conda/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->RISE) (0.1.7)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->RISE) (1.6.0)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->RISE) (5.9.8)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=6.0->RISE) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=6.0->RISE) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=6.0->RISE) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=6.0->RISE) (0.20.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (2.9.0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (4.3.2)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/conda/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /opt/conda/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /opt/conda/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/conda/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /opt/conda/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (6.1.0)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/conda/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/conda/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in /opt/conda/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (2.18.0)
# Requirement already satisfied: tinycss2 in /opt/conda/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (1.3.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/conda/lib/python3.11/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (2.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=6.0->RISE) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=6.0->RISE) (2.2.2)
# Requirement already satisfied: ptyprocess in /opt/conda/lib/python3.11/site-packages (from terminado>=0.8.3->jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (0.7.0)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/lib/python3.11/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (1.16.0)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.11/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (0.5.1)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->RISE) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->RISE) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/conda/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->RISE) (3.0.47)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->RISE) (0.6.2)
# Requirement already satisfied: typing-extensions>=4.6 in /opt/conda/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->RISE) (4.12.2)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->RISE) (4.9.0)
# Requirement already satisfied: fqdn in /opt/conda/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (1.5.1)
# Requirement already satisfied: isoduration in /opt/conda/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/conda/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (3.0.0)
# Requirement already satisfied: uri-template in /opt/conda/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /opt/conda/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (24.8.0)
# Requirement already satisfied: cffi>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (2.5)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/lib/python3.11/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->RISE) (0.8.4)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->RISE) (0.2.13)
# Requirement already satisfied: arrow>=0.15.0 in /opt/conda/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (1.3.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->RISE) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->RISE) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->RISE) (0.2.3)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /opt/conda/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.0->RISE) (2.9.0.20240906)
# Using cached rise-5.7.1-py2.py3-none-any.whl (4.3 MB)
# Installing collected packages: RISE
# Successfully installed RISE-5.7.1

# %% [markdown]
# ### Importing income data for LA County

# %%
import pandas as pd

# %%
import geopandas as gpd

# %%
df = pd.read_csv('/home/jovyan/221-final-project/Group Assignments/Income/data/findata/ACSST5Y2023.S2503-Data.csv', low_memory=False)

# %%
df.shape
# Out:
# (2499, 555)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df.sample(5)
# Out:
#                     GEO_ID                                               NAME  \
# 1367  1400000US06037408627  Census Tract 4086.27; Los Angeles County; Cali...
# 133   1400000US06037117302  Census Tract 1173.02; Los Angeles County; Cali...
# 142   1400000US06037119001  Census Tract 1190.01; Los Angeles County; Cali...
# 78    1400000US06037109601  Census Tract 1096.01; Los Angeles County; Cali...
# 293   1400000US06037133000  Census Tract 1330; Los Angeles County; California
#
#      S2503_C01_001E S2503_C01_001M S2503_C01_002E S2503_C01_002M  \
# 1367            865             94             23             25
# 133            1603            122             15             25
# 142            1031            120             11             17
# 78             1330            165             18             17
# 293            1386            216             55             46
#
#      S2503_C01_003E S2503_C01_003M S2503_C01_004E S2503_C01_004M  \
# 1367             45             38              5              8
# 133              25             27             24             26
# 142               5             10              7              9
# 78                0             19             32             34
# 293               0             14             29             50
#
#      S2503_C01_005E S2503_C01_005M S2503_C01_006E S2503_C01_006M  \
# 1367              6              8              9             13
# 133              61             62             71             63
# 142              15             18             10             13
# 78                0             19             38             45
# 293              22             34              7             11
#
#      S2503_C01_007E S2503_C01_007M S2503_C01_008E S2503_C01_008M  \
# 1367             16             15             45             22
# 133              26             31             18             21
# 142              36             42             41             23
# 78               22             25            129             91
# 293              94             88             17             22
#
#      S2503_C01_009E S2503_C01_009M S2503_C01_010E S2503_C01_010M  \
# 1367            151             61            147             59
# 133             193             85            232            109
# 142             181             81            136             91
# 78              124             75            171             71
# 293             285            188            182             90
#
# 133             104             69            452             92
# 142               0             14            297             75
# 78              234            161            302            103
# 293             439            190            230            109
#
#      S2503_C03_023E S2503_C03_023M S2503_C03_024E S2503_C03_024M  \
# 1367            (X)            (X)           2209            301
# 133             (X)            (X)           2113            673
# 142             (X)            (X)           2098            223
# 78              (X)            (X)           2434            261
# 293             (X)            (X)           2678            114
#
#      S2503_C03_025E S2503_C03_025M S2503_C03_026E S2503_C03_026M  \
# 1367             56             38              0             14
# 133              41             32              0             14
# 142              27             19              0             14
# 78               38             29              0             19
# 293              59             53              0             14
#
#      S2503_C03_027E S2503_C03_027M S2503_C03_028E S2503_C03_028M  \
# 1367              0             14             56             38
# 133               0             14             41             32
# 142               0             14             27             19
# 78                0             19             38             29
# 293               0             14             59             53
#
#      S2503_C03_029E S2503_C03_029M S2503_C03_030E S2503_C03_030M  \
# 1367             25             19              0             14
# 133              79             64             17             21
# 142               9             12              0             14
# 78               60             51              0             19
# 293              58             74              0             14
#
#      S2503_C03_031E S2503_C03_031M S2503_C03_032E S2503_C03_032M  \
# 1367              4              7             21             17
# 133               0             14             62             61
# 142               5              9              4              7
# 78                6             10             54             50
# 293               0             14             58             74
#
#      S2503_C03_033E S2503_C03_033M S2503_C03_034E S2503_C03_034M  \
# 1367             45             22              5              8
# 133              18             21              0             14
# 142              41             23             17             17
# 78               86             72              0             19
# 293              17             22              0             14
#
#      S2503_C03_035E S2503_C03_035M S2503_C03_036E S2503_C03_036M  \
# 1367              0             14             40             22
# 133               9             14              9             15
# 142               6              8             18             17
# 78                0             19             86             72
# 293               8             14              9             17
#
#      S2503_C03_037E S2503_C03_037M S2503_C03_038E S2503_C03_038M  \
# 1367            142             57             35             23
# 133              84             48             19             20
# 142             144             70             41             29
# 78               90             62             13             17
# 293             268            192             86            105
#
#      S2503_C03_039E S2503_C03_039M S2503_C03_040E S2503_C03_040M  \
# 1367             30             25             77             50
# 133              20             21             45             42
# 142              13             14             90             61
# 78                4              7             73             56
# 293              45             48            137            152
#
#      S2503_C03_041E S2503_C03_041M S2503_C03_042E S2503_C03_042M  \
# 1367            470             82            265             57
# 133             986            125            591            133
# 142             640            141            317             85
# 78              859            178            290            110
# 293             623            151            262             94
#
#      S2503_C03_043E S2503_C03_043M S2503_C03_044E S2503_C03_044M  \
# 1367             88             44            117             52
# 133             157             76            238            101
# 142             172             83            151             98
# 78              329            153            240             95
# 293             184            107            177            112
#
#      S2503_C03_045E S2503_C03_045M S2503_C03_046E S2503_C03_046M  \
# 1367              5              7            (X)            (X)
# 133               0             14            (X)            (X)
# 142               0             14            (X)            (X)
# 78                0             19            (X)            (X)
# 293               0             14            (X)            (X)
#
#      S2503_C04_001E S2503_C04_001M S2503_C04_002E S2503_C04_002M  \
# 1367            743            105            0.7            1.0
# 133            1208            126            0.0            3.5
# 142             861            130            0.0            4.8
# 78             1133            176            1.6            1.5
# 293            1025            229            3.6            3.4
#
#      S2503_C04_003E S2503_C04_003M S2503_C04_004E S2503_C04_004M  \
# 1367            6.1            5.0            0.7            1.1
# 133             0.4            0.6            2.0            2.1
# 78             21.8           26.0            0.0           19.3
# 293             0.0           11.1            0.0           11.1
#
#      S2503_C06_035E S2503_C06_035M S2503_C06_036E S2503_C06_036M  \
# 1367            0.0           28.7            0.0           28.7
# 133             0.0           10.2            0.0           10.2
# 142             0.0           21.9            0.0           21.9
# 78              0.0           19.3           21.8           26.0
# 293             0.0           11.1            0.0           11.1
#
#      S2503_C06_037E S2503_C06_037M S2503_C06_038E S2503_C06_038M  \
# 1367            7.4           10.8            0.0           28.7
# 133            25.1           17.1            0.0           10.2
# 142            20.0           18.0            0.0           21.9
# 78             17.3           26.5            0.0           19.3
# 293             4.7            5.8            0.0           11.1
#
#      S2503_C06_039E S2503_C06_039M S2503_C06_040E S2503_C06_040M  \
# 1367            0.0           28.7            7.4           10.8
# 133             2.3            4.1           22.8           16.6
# 142             3.5            5.8           16.5           17.6
# 78              0.0           19.3           17.3           26.5
# 293             0.0           11.1            4.7            5.8
#
#      S2503_C06_041E S2503_C06_041M S2503_C06_042E S2503_C06_042M  \
# 1367           73.0           22.3           18.0           17.9
# 133            46.6           16.6           16.2           12.9
# 142            50.0           21.4           22.9           16.6
# 78             54.8           32.1           16.2           19.1
# 293            60.4           23.5           36.6           24.4
#
#      S2503_C06_043E S2503_C06_043M S2503_C06_044E S2503_C06_044M  \
# 1367           23.8           26.8           31.1           25.2
# 133             8.9           11.6           21.5           10.8
# 142            21.2           15.5            5.9            9.7
# 78             23.9           25.2           14.7           19.6
# 293             7.8           11.6           16.1           17.6
#
#      S2503_C06_045E S2503_C06_045M S2503_C06_046E S2503_C06_046M  Unnamed: 554
# 1367           14.8           18.5            4.9            7.9           NaN
# 133             0.0           10.2            2.5            3.9           NaN
# 142             0.0           21.9            5.3            7.3           NaN
# 78              0.0           19.3            0.0           19.3           NaN
# 293             5.0            7.6           10.0           14.4           NaN

# %%
df.GEO_ID.head()
# Out:
# 0               Geography
# 1    1400000US06037101110
# 2    1400000US06037101122
# 3    1400000US06037101220
# 4    1400000US06037101221
# Name: GEO_ID, dtype: object

# %% [markdown]
# ### Extracting FIPS codes

# %%
df['FIPS'] = df['GEO_ID'].str[-11:]

# %%
print(df[['GEO_ID', 'FIPS']].head())
# Out:
#                  GEO_ID         FIPS
# 0             Geography    Geography
# 1  1400000US06037101110  06037101110
# 2  1400000US06037101122  06037101122
# 3  1400000US06037101220  06037101220
# 4  1400000US06037101221  06037101221

# %% [markdown]
# ### Cleaning and reducing data

# %%
df.columns[df.isna().all()].tolist()
# Out:
# ['Unnamed: 554']

# %%
df = df.dropna(axis=1,how="all")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2499 entries, 0 to 2498
# Columns: 555 entries, GEO_ID to FIPS
# dtypes: object(555)
# memory usage: 10.6+ MB

# %%
columns_to_keep = ['FIPS',
                   'S2503_C01_013E',
                   'S2503_C01_024E',
                   'S2503_C02_013E',
                   'S2503_C02_024E',
                   'S2503_C03_013E',
                   'S2503_C03_024E',
                   'S2503_C04_013E',
                   'S2503_C04_024E',
                   'S2503_C05_013E',
                   'S2503_C05_024E',
                    'S2503_C06_013E',
                   'S2503_C06_024E']
df2 = df[columns_to_keep]

# %%
df2.columns= ['FIPS',
'MedHHIncome_All',
'MonthlyCosts_All',
'MedHHIncome_OwnerOccupied',
'MonthlyCosts_OwnerOccupied',
'MedHHIncome_RenterOccupied',
'MonthlyCosts_RenterOccupied',
'MedHHIncome_Mixed',
'MonthlyCosts_Mixed',
'MedHHIncome_NoMortgage',
'MonthlyCosts_NoMortgage',
'MedHHIncome_Mortgage',
'MonthlyCosts_Mortgage']

# %%
df2.sample(5)
# Out:
#              FIPS MedHHIncome_All MonthlyCosts_All MedHHIncome_OwnerOccupied  \
# 610   06037208301           42548             1470                     42548
# 2389  06037910719           95577             2349                     95577
# 1839  06037544002          110179             2090                    110179
# 1465  06037460800        250,000+           4,000+                  250,000+
# 2465  06037980006               -                -                         -
#
#      MonthlyCosts_OwnerOccupied MedHHIncome_RenterOccupied  \
# 610                        1470                          -
# 2389                       2349                     115400
# 1839                       2090                     114943
# 1465                     4,000+                   250,000+
# 2465                          -                          -
#
#      MonthlyCosts_RenterOccupied MedHHIncome_Mixed MonthlyCosts_Mixed  \
# 610                            -                 -                  -
# 2389                        2378            115400               2378
# 1839                        2174            114943               2174
# 1465                      4,000+          250,000+             4,000+
# 2465                           -                 -                  -
#
#      MedHHIncome_NoMortgage MonthlyCosts_NoMortgage MedHHIncome_Mortgage  \
# 610                   44135                    1509                44135
# 2389                      -                    1934                    -
# 1839                  76833                    2000                76833
# 1465               250,000+                    3420             250,000+
# 2465                      -                       -                    -
#
#      MonthlyCosts_Mortgage
# 610                   1509
# 2389                  1934
# 1839                  2000
# 1465                  3420
# 2465                     -

# %%
print (df2.dtypes)
# Out:
# FIPS                           object
# MedHHIncome_All                object
# MonthlyCosts_All               object
# MedHHIncome_OwnerOccupied      object
# MonthlyCosts_OwnerOccupied     object
# MedHHIncome_RenterOccupied     object
# MonthlyCosts_RenterOccupied    object
# MedHHIncome_Mixed              object
# MonthlyCosts_Mixed             object
# MedHHIncome_NoMortgage         object
# MonthlyCosts_NoMortgage        object
# MedHHIncome_Mortgage           object
# MonthlyCosts_Mortgage          object
# dtype: object

# %%
columns_to_convert = ['MedHHIncome_All',
'MonthlyCosts_All',
'MedHHIncome_OwnerOccupied',
'MonthlyCosts_OwnerOccupied',
'MedHHIncome_RenterOccupied',
'MonthlyCosts_RenterOccupied',
'MedHHIncome_Mixed',
'MonthlyCosts_Mixed',
'MedHHIncome_NoMortgage',
'MonthlyCosts_NoMortgage',
'MedHHIncome_Mortgage',
'MonthlyCosts_Mortgage']

# %%
# Ensure df2 is an independent copy before modifying
df2 = df2.copy()

# Convert all columns except "FIPS" to numeric
columns_to_convert = [col for col in df2.columns if col != "FIPS"]
df2.loc[:, columns_to_convert] = df2[columns_to_convert].apply(pd.to_numeric, errors="coerce")

# %%
df2.dtypes
# Out:
# FIPS                           object
# MedHHIncome_All                object
# MonthlyCosts_All               object
# MedHHIncome_OwnerOccupied      object
# MonthlyCosts_OwnerOccupied     object
# MedHHIncome_RenterOccupied     object
# MonthlyCosts_RenterOccupied    object
# MedHHIncome_Mixed              object
# MonthlyCosts_Mixed             object
# MedHHIncome_NoMortgage         object
# MonthlyCosts_NoMortgage        object
# MedHHIncome_Mortgage           object
# MonthlyCosts_Mortgage          object
# dtype: object

# %% [markdown]
# ### Mapping Income Data

# %%
pip install geopandas folium matplotlib
# Out:
# Requirement already satisfied: geopandas in /opt/conda/lib/python3.11/site-packages (1.0.1)
# Requirement already satisfied: folium in /opt/conda/lib/python3.11/site-packages (0.19.4)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.11/site-packages (3.9.2)
# Requirement already satisfied: numpy>=1.22 in /opt/conda/lib/python3.11/site-packages (from geopandas) (2.0.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /opt/conda/lib/python3.11/site-packages (from geopandas) (0.10.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from geopandas) (24.1)
# Requirement already satisfied: pandas>=1.4.0 in /opt/conda/lib/python3.11/site-packages (from geopandas) (2.2.2)
# Requirement already satisfied: pyproj>=3.3.0 in /opt/conda/lib/python3.11/site-packages (from geopandas) (3.7.0)
# Requirement already satisfied: shapely>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from geopandas) (2.0.6)
# Requirement already satisfied: branca>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/lib/python3.11/site-packages (from folium) (3.1.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /opt/conda/lib/python3.11/site-packages (from folium) (2024.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (2.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.4.0->geopandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.4.0->geopandas) (2024.1)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from pyogrio>=0.7.2->geopandas) (2024.12.14)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->folium) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->folium) (2.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

# %%
tracts=gpd.read_file('data/Census_Tracts_2020.geojson')
tracts.head()
# Out:
#    OBJECTID    CT20    LABEL   ShapeSTArea  ShapeSTLength  \
# 0         1  101110  1011.10  1.229562e+07   15083.854287
# 1         2  101122  1011.22  2.845774e+07   31671.455844
# 2         3  101220  1012.20  7.522093e+06   12698.783810
# 3         4  101221  1012.21  3.812000e+06    9161.710543
# 4         5  101222  1012.22  3.191371e+06    9980.600461
#
#                                             geometry
# 0  POLYGON ((-118.28491 34.25948, -118.28492 34.2...
# 1  POLYGON ((-118.29015 34.27417, -118.29015 34.2...
# 2  POLYGON ((-118.281 34.25592, -118.28198 34.255...
# 3  POLYGON ((-118.28735 34.25591, -118.28863 34.2...
# 4  POLYGON ((-118.28594 34.25405, -118.28594 34.2...

# %%
tracts = tracts[['CT20','geometry']]
tracts.head()
# Out:
#      CT20                                           geometry
# 0  101110  POLYGON ((-118.28491 34.25948, -118.28492 34.2...
# 1  101122  POLYGON ((-118.29015 34.27417, -118.29015 34.2...
# 2  101220  POLYGON ((-118.281 34.25592, -118.28198 34.255...
# 3  101221  POLYGON ((-118.28735 34.25591, -118.28863 34.2...
# 4  101222  POLYGON ((-118.28594 34.25405, -118.28594 34.2...

# %%
tracts['FIPS'] ='06' + '037' + tracts['CT20']
tracts.head()
# Out:
#      CT20                                           geometry         FIPS
# 0  101110  POLYGON ((-118.28491 34.25948, -118.28492 34.2...  06037101110
# 1  101122  POLYGON ((-118.29015 34.27417, -118.29015 34.2...  06037101122
# 2  101220  POLYGON ((-118.281 34.25592, -118.28198 34.255...  06037101220
# 3  101221  POLYGON ((-118.28735 34.25591, -118.28863 34.2...  06037101221
# 4  101222  POLYGON ((-118.28594 34.25405, -118.28594 34.2...  06037101222

# %%
df2 = df2.copy()

# %%
# Ensure df2["FIPS"] is a string, removing any unexpected values
df2 = df2[df2["FIPS"].str.isnumeric()]  # Keep only numeric values
df2["FIPS"] = df2["FIPS"].astype(float).astype(int).astype(str).str.zfill(11)

# %%
# Ensure tracts["FIPS"] is also a string
tracts["FIPS"] = tracts["FIPS"].astype(str)

# %%
# Merge the cleaned df2 with the GeoJSON tracts dataset
tracts_income = tracts.merge(df2, on="FIPS", how="left")

# %%
df2.sample(5)
# Out:
#              FIPS MedHHIncome_All MonthlyCosts_All MedHHIncome_OwnerOccupied  \
# 2193  06037650603        117019.0           1800.0                  117019.0
# 1821  06037543501        105518.0           1627.0                  105518.0
# 848   06037236400        106107.0           2231.0                  106107.0
# 303   06037134303        109063.0           2374.0                  109063.0
# 812   06037231901         88702.0           1802.0                   88702.0
#
#      MonthlyCosts_OwnerOccupied MedHHIncome_RenterOccupied  \
# 2193                     1800.0                   121906.0
# 1821                     1627.0                   134630.0
# 848                      2231.0                   143182.0
# 303                      2374.0                    97404.0
# 812                      1802.0                   130095.0
#
#      MonthlyCosts_RenterOccupied MedHHIncome_Mixed MonthlyCosts_Mixed  \
# 2193                      1909.0          121906.0             1909.0
# 1821                      1848.0          134630.0             1848.0
# 848                       3537.0          143182.0             3537.0
# 303                       2117.0           97404.0             2117.0
# 812                       1968.0          130095.0             1968.0
#
#      MedHHIncome_NoMortgage MonthlyCosts_NoMortgage MedHHIncome_Mortgage  \
# 2193                83854.0                  1893.0              83854.0
# 1821                83016.0                  1648.0              83016.0
# 848                 85341.0                  1858.0              85341.0
# 303                112019.0                  2658.0             112019.0
# 812                     NaN                  1552.0                  NaN
#
#      MonthlyCosts_Mortgage
# 2193                1893.0
# 1821                1648.0
# 848                 1858.0
# 303                 2658.0
# 812                 1552.0

# %%
tracts.sample(5)
# Out:
#         CT20                                           geometry         FIPS
# 2333  900902  POLYGON ((-118.14009 34.82078, -118.14009 34.8...  06037900902
# 946   265522  POLYGON ((-118.44239 34.05303, -118.44156 34.0...  06037265522
# 469   190802  POLYGON ((-118.33247 34.09799, -118.33322 34.0...  06037190802
# 2487  980031  POLYGON ((-118.26315 33.76749, -118.26339 33.7...  06037980031
# 387   143801  POLYGON ((-118.38062 34.13828, -118.38063 34.1...  06037143801

# %%
tracts_income.sample(5)
# Out:
#         CT20                                           geometry         FIPS  \
# 1000  271901  POLYGON ((-118.42379 34.009, -118.42303 34.009...  06037271901
# 1411  431701  POLYGON ((-118.03109 34.12094, -118.03111 34.1...  06037431701
# 740   221120  POLYGON ((-118.28413 34.04184, -118.28414 34.0...  06037221120
# 1371  408705  POLYGON ((-117.87231 33.98621, -117.87245 33.9...  06037408705
# 1547  481714  POLYGON ((-118.12287 34.06616, -118.12449 34.0...  06037481714
#
#      MedHHIncome_All MonthlyCosts_All MedHHIncome_OwnerOccupied  \
# 1000        119561.0           2332.0                  119561.0
# 1411        117138.0           3493.0                  117138.0
# 740          47368.0           1404.0                   47368.0
# 1371         70000.0           2028.0                   70000.0
# 1547         42713.0           1416.0                   42713.0
#
#      MonthlyCosts_OwnerOccupied MedHHIncome_RenterOccupied  \
# 1000                     2332.0                   140677.0
# 1411                     3493.0                   146250.0
# 740                      1404.0                        NaN
# 1371                     2028.0                    62212.0
# 1547                     1416.0                    80156.0
#
#      MonthlyCosts_RenterOccupied MedHHIncome_Mixed MonthlyCosts_Mixed  \
# 1000                      1223.0          140677.0             1223.0
# 1411                      3834.0          146250.0             3834.0
# 740                          NaN               NaN                NaN
# 1371                      1909.0           62212.0             1909.0
# 1547                      1174.0           80156.0             1174.0
#
#      MedHHIncome_NoMortgage MonthlyCosts_NoMortgage MedHHIncome_Mortgage  \
# 1000               119276.0                  2564.0             119276.0
# 1411                66347.0                  2039.0              66347.0
# 740                 46591.0                  1401.0              46591.0
# 1371                77961.0                  2154.0              77961.0
# 1547                30500.0                  1497.0              30500.0
#
#      MonthlyCosts_Mortgage
# 1000                2564.0
# 1411                2039.0
# 740                 1401.0
# 1371                2154.0
# 1547                1497.0

# %%
tracts_income.plot(figsize=(12,10),
                 column='MedHHIncome_All',
                 legend=True, 
                 scheme='naturalbreaks')
# Out:
# <Axes: >

# %%
tracts_income.plot(figsize=(12,10),
                 column='MonthlyCosts_All',
                 legend=True, 
                 scheme='equal_interval')
# Out:
# <Axes: >

# %% [markdown]
# ### I am interested in plotting monthly housing costs as a percentage of monthly income

# %%
#Adding new column: # Avoid division by zero (replace zero or NaN incomes with NaN)
tracts_income["HousingCostPercentage"] = (
    (tracts_income["MonthlyCosts_All"] / (tracts_income["MedHHIncome_All"] / 12)) * 100
)

# %%
tracts_income.plot(figsize=(12,10),
                 column='HousingCostPercentage',
                 legend=True, 
                 scheme='naturalbreaks')
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
import geopandas as gpd
import matplotlib as mpl

# Assuming 'tracts_income' is already your GeoDataFrame

# Create the figure and axis with adjusted size
fig, ax = plt.subplots(figsize=(10, 10))

# Plot the data, using the 'MedHHIncome_All' column to set the color
# Use 'Reds' or any other color map you prefer
gdf_plot = tracts_income.plot(
    ax=ax,
    column='MedHHIncome_All',  # Column to be used for coloring
    cmap='Reds',  # Color map for gradient
    legend=False,  # Disable default legend
    alpha=0.7  # Make the polygons slightly transparent for better visibility
)

# Add a colorbar (this acts as the gradient bar)
sm = plt.cm.ScalarMappable(cmap='Reds', norm=plt.Normalize(vmin=tracts_income['MedHHIncome_All'].min(), vmax=tracts_income['MedHHIncome_All'].max()))
sm.set_array([])  # We don't need any data associated with the colorbar
cbar = plt.colorbar(sm, ax=ax, orientation='horizontal', pad=0.02)
cbar.set_label('Median Household Income', fontsize=12)

# Title and styling
ax.set_title('Median Household Income, 2024', fontsize=16)
ax.axis('off')  # Remove axis for better visualization

# Save the plot to a file with adjusted DPI and size
plt.savefig('MedHHIncome.jpg', dpi=150, bbox_inches='tight')

# Show the plot
plt.show()

plt.savefig('221-final-project/Group Assignments/Income/medHHincomeLAplot.jpg', dpi=150)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[38], line 36
#      33 # Show the plot
#      34 plt.show()
# ---> 36 plt.savefig('221-final-project/Group Assignments/Income/medHHincomeLAplot.jpg', dpi=150)
#
# File /opt/conda/lib/python3.11/site-packages/matplotlib/pyplot.py:1228, in savefig(*args, **kwargs)
#    1225 fig = gcf()
#    1226 # savefig default implementation has no return, so mypy is unhappy
#    1227 # presumably this is here because subclasses can return?
# -> 1228 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1229 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1230 return res
#
# File /opt/conda/lib/python3.11/site-packages/matplotlib/figure.py:3395, in Figure.savefig(self, fname, transparent, **kwargs)
#    3393     for ax in self.axes:
#    3394         _recursively_make_axes_transparent(stack, ax)
# -> 3395 self.canvas.print_figure(fname, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/matplotlib/backend_bases.py:2204, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2200 try:
#    2201     # _get_renderer may change the figure dpi (as vector formats
#    2202     # force the figure dpi to 72), so we need to set it again here.
#    2203     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2204         result = print_method(
#    2205             filename,
#    2206             facecolor=facecolor,
#    2207             edgecolor=edgecolor,
#    2208             orientation=orientation,
#    2209             bbox_inches_restore=_bbox_inches_restore,
#    2210             **kwargs)
#    2211 finally:
#    2212     if bbox_inches and restore_bbox:
#
# File /opt/conda/lib/python3.11/site-packages/matplotlib/backend_bases.py:2054, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2050     optional_kws = {  # Passed by print_figure for other renderers.
#    2051         "dpi", "facecolor", "edgecolor", "orientation",
#    2052         "bbox_inches_restore"}
#    2053     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2054     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2055         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2056 else:  # Let third-parties do as they see fit.
#    2057     print_method = meth
#
# File /opt/conda/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:513, in FigureCanvasAgg.print_jpg(self, filename_or_obj, metadata, pil_kwargs)
#     508 def print_jpg(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     509     # savefig() has already applied savefig.facecolor; we now set it to
#     510     # white to make imsave() blend semi-transparent figures against an
#     511     # assumed white background.
#     512     with mpl.rc_context({"savefig.facecolor": "white"}):
# --> 513         self._print_pil(filename_or_obj, "jpeg", pil_kwargs, metadata)
#
# File /opt/conda/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:445, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     440 """
#     441 Draw the canvas, then save it using `.image.imsave` (to which
#     442 *pil_kwargs* and *metadata* are forwarded).
#     443 """
#     444 FigureCanvasAgg.draw(self)
# --> 445 mpl.image.imsave(
#     446     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     447     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/matplotlib/image.py:1676, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1674 pil_kwargs.setdefault("format", format)
#    1675 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1676 image.save(fname, **pil_kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/PIL/Image.py:2563, in Image.save(self, fp, format, **params)
#    2561         fp = builtins.open(filename, "r+b")
#    2562     else:
# -> 2563         fp = builtins.open(filename, "w+b")
#    2564 else:
#    2565     fp = cast(IO[bytes], fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/jovyan/221-final-project/Group Assignments/Income/221-final-project/Group Assignments/Income/medHHincomeLAplot.jpg'

# %%
fig, ax = plt.subplots(figsize=(10, 10))

# Plot the data, using the 'MedHHIncome_All' column to set the color
# Use 'Reds' or any other color map you prefer
gdf_plot = tracts_income.plot(
    ax=ax,
    column='MonthlyCosts_All',  # Column to be used for coloring
    cmap='Reds',  # Color map for gradient
    legend=False,  # Disable default legend
    alpha=0.7  # Make the polygons slightly transparent for better visibility
)

# Add a colorbar (this acts as the gradient bar)
sm = plt.cm.ScalarMappable(cmap='Reds', norm=plt.Normalize(vmin=tracts_income['MonthlyCosts_All'].min(), vmax=tracts_income['MonthlyCosts_All'].max()))
sm.set_array([])  # We don't need any data associated with the colorbar
cbar = plt.colorbar(sm, ax=ax, orientation='horizontal', pad=0.02)
cbar.set_label('Monthly Household Costs', fontsize=12)

# Title and styling
ax.set_title('Median Monthly Housing Costs, 2024', fontsize=16)
ax.axis('off')  # Remove axis for better visualization

# Save the plot to a file with adjusted DPI and size
plt.savefig('MedHHCosts.jpg', dpi=150, bbox_inches='tight')

# Show the plot
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 10))

# Plot the data, using the 'MedHHIncome_All' column to set the color
# Use 'Reds' or any other color map you prefer
gdf_plot = tracts_income.plot(
    ax=ax,
    column='HousingCostPercentage',  # Column to be used for coloring
    cmap='Reds',  # Color map for gradient
    legend=False,  # Disable default legend
    alpha=0.7  # Make the polygons slightly transparent for better visibility
)

# Add a colorbar (this acts as the gradient bar)
sm = plt.cm.ScalarMappable(cmap='Reds', norm=plt.Normalize(vmin=tracts_income['HousingCostPercentage'].min(), vmax=tracts_income['HousingCostPercentage'].max()))
sm.set_array([])  # We don't need any data associated with the colorbar
cbar = plt.colorbar(sm, ax=ax, orientation='horizontal', pad=0.02)
cbar.set_label('Monthly Housing Costs as a Percentage of Income', fontsize=12)

# Title and styling
ax.set_title('Median Monthly Housing Costs as a Percentage of Income, 2024', fontsize=16)
ax.axis('off')  # Remove axis for better visualization

# Save the plot to a file with adjusted DPI and size
plt.savefig('MedHHCostsIncome.jpg', dpi=150, bbox_inches='tight')

# Show the plot
plt.show()

# %%
df2.sample()
# Out:
#              FIPS MedHHIncome_All MonthlyCosts_All MedHHIncome_OwnerOccupied  \
# 1564  06037482502         73125.0           1376.0                   73125.0
#
#      MonthlyCosts_OwnerOccupied MedHHIncome_RenterOccupied  \
# 1564                     1376.0                    98958.0
#
#      MonthlyCosts_RenterOccupied MedHHIncome_Mixed MonthlyCosts_Mixed  \
# 1564                       699.0           98958.0              699.0
#
#      MedHHIncome_NoMortgage MonthlyCosts_NoMortgage MedHHIncome_Mortgage  \
# 1564                58510.0                  1743.0              58510.0
#
#      MonthlyCosts_Mortgage
# 1564                1743.0

# %%
print(tracts_income.columns)
# Out:
# Index(['CT20', 'geometry', 'FIPS', 'MedHHIncome_All', 'MonthlyCosts_All',
#        'MedHHIncome_OwnerOccupied', 'MonthlyCosts_OwnerOccupied',
#        'MedHHIncome_RenterOccupied', 'MonthlyCosts_RenterOccupied',
#        'MedHHIncome_Mixed', 'MonthlyCosts_Mixed', 'MedHHIncome_NoMortgage',
#        'MonthlyCosts_NoMortgage', 'MedHHIncome_Mortgage',
#        'MonthlyCosts_Mortgage', 'HousingCostPercentage'],
#       dtype='object')

# %%
tracts_income.sample(1)
# Out:
#        CT20                                           geometry         FIPS  \
# 780  228100  POLYGON ((-118.23972 34.01472, -118.23972 34.0...  06037228100
#
#     MedHHIncome_All MonthlyCosts_All MedHHIncome_OwnerOccupied  \
# 780         49291.0           1817.0                   49291.0
#
#     MonthlyCosts_OwnerOccupied MedHHIncome_RenterOccupied  \
# 780                     1817.0                        NaN
#
#     MonthlyCosts_RenterOccupied MedHHIncome_Mixed MonthlyCosts_Mixed  \
# 780                      2189.0               NaN             2189.0
#
#     MedHHIncome_NoMortgage MonthlyCosts_NoMortgage MedHHIncome_Mortgage  \
# 780                53689.0                  1440.0              53689.0
#
#     MonthlyCosts_Mortgage HousingCostPercentage
# 780                1440.0             44.235256

# %%
import matplotlib.pyplot as plt
import geopandas as gpd
import os  # To check and create directories if needed

# Define bounding boxes for Downtown LA and South Central LA
downtown_bounds = [-118.2673, 34.027, -118.2257, 34.076]  # [min_long, min_lat, max_long, max_lat]
south_central_bounds = [-118.28, 33.9, -118.18, 34.03]  # [min_long, min_lat, max_long, max_lat]

# Function to filter GeoDataFrame based on bounding box
def filter_by_bounding_box(gdf, bounds):
    min_long, min_lat, max_long, max_lat = bounds
    return gdf.cx[min_long:max_long, min_lat:max_lat]

# Plotting function
def plot_static_map(gdf, title, filename, cmap='Reds', bounds=None):
    fig, ax = plt.subplots(figsize=(10, 10))

    # Apply bounding box if provided
    if bounds:
        gdf = filter_by_bounding_box(gdf, bounds)

    # Plot the data, using the 'HousingCostPercentage' column to set the color
    gdf.plot(
        ax=ax,
        column='HousingCostPercentage',  # Column to be used for coloring
        cmap=cmap,  # Color map for gradient
        legend=False,  # Disable default legend
        alpha=0.7  # Make the polygons slightly transparent for better visibility
    )

    # Add a colorbar (this acts as the gradient bar)
    sm = plt.cm.ScalarMappable(cmap=cmap, norm=plt.Normalize(vmin=gdf['HousingCostPercentage'].min(), vmax=gdf['HousingCostPercentage'].max()))
    sm.set_array([])  # We don't need any data associated with the colorbar
    cbar = plt.colorbar(sm, ax=ax, orientation='horizontal', pad=0.02)
    cbar.set_label('Monthly Housing Costs as a Percentage of Income', fontsize=12)

    # Title and styling
    ax.set_title(title, fontsize=16)
    ax.axis('off')  # Remove axis for better visualization

    # Ensure the output directory exists
    output_dir = os.path.dirname(filename)
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # Save the plot to a file with adjusted DPI and size
    plt.savefig(filename, dpi=150, bbox_inches='tight')

    # Show the plot
    plt.show()


# File paths for saving
downtown_filename = '/home/jovyan/work/output/downtown_housing_costs.jpg'
south_central_filename = '/home/jovyan/work/output/south_central_housing_costs.jpg'

# Plot Downtown LA (using bounding box for zooming)
plot_static_map(tracts_income, "Housing Costs as a Percentage of Income - Downtown LA, 2024", downtown_filename, bounds=downtown_bounds)

# Plot South Central LA (using bounding box for zooming)
plot_static_map(tracts_income, "Housing Costs as a Percentage of Income - South Central LA, 2024", south_central_filename, bounds=south_central_bounds)

# %%
import matplotlib.pyplot as plt
import geopandas as gpd
import matplotlib as mpl
import os  # To check and create directories if needed

# Define bounding boxes for Downtown LA and South Central LA
downtown_bounds = [-118.2673, 34.027, -118.2257, 34.076]  # [min_long, min_lat, max_long, max_lat]
south_central_bounds = [-118.28, 33.9, -118.18, 34.03]  # [min_long, min_lat, max_long, max_lat]

# Function to filter GeoDataFrame based on bounding box
def filter_by_bounding_box(gdf, bounds):
    min_long, min_lat, max_long, max_lat = bounds
    return gdf.cx[min_long:max_long, min_lat:max_lat]

# Plotting function
def plot_static_map(gdf, title, filename, cmap='Reds', bounds=None):
    fig, ax = plt.subplots(figsize=(10, 10))

    # Apply bounding box if provided
    if bounds:
        gdf = filter_by_bounding_box(gdf, bounds)

    # Plot the data, using the 'MedHHIncome_All' column to set the color
    gdf.plot(
        ax=ax,
        column='MedHHIncome_All',  # Column to be used for coloring
        cmap=cmap,  # Color map for gradient
        legend=False,  # Disable default legend
        alpha=0.7  # Make the polygons slightly transparent for better visibility
    )

    # Add a colorbar (this acts as the gradient bar)
    sm = plt.cm.ScalarMappable(cmap=cmap, norm=plt.Normalize(vmin=gdf['MedHHIncome_All'].min(), vmax=gdf['MedHHIncome_All'].max()))
    sm.set_array([])  # We don't need any data associated with the colorbar
    cbar = plt.colorbar(sm, ax=ax, orientation='horizontal', pad=0.02)
    cbar.set_label('Median Household Income', fontsize=12)

    # Title and styling
    ax.set_title(title, fontsize=16)
    ax.axis('off')  # Remove axis for better visualization

    # Ensure the output directory exists
    output_dir = os.path.dirname(filename)
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # Save the plot to a file with adjusted DPI and size
    plt.savefig(filename, dpi=150, bbox_inches='tight')

    # Show the plot
    plt.show()


# File paths for saving
downtown_filename = '/home/jovyan/work/output/downtown_housing_income.jpg'
south_central_filename = '/home/jovyan/work/output/south_central_housing_income.jpg'

# Plot Downtown LA (using bounding box for zooming)
plot_static_map(tracts_income, "Median Household Income - Downtown LA, 2024", downtown_filename, bounds=downtown_bounds)

# Plot South Central LA (using bounding box for zooming)
plot_static_map(tracts_income, "Median Household Income - South Central LA, 2024", south_central_filename, bounds=south_central_bounds)

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Function to calculate average values for a specific column within a bounding box
def calculate_average_within_bounds(gdf, column, bounds):
    filtered_gdf = filter_by_bounding_box(gdf, bounds)
    return filtered_gdf[column].mean()

# Calculate averages for each region
average_income_downtown = calculate_average_within_bounds(tracts_income, 'MedHHIncome_All', downtown_bounds)
average_income_south_central = calculate_average_within_bounds(tracts_income, 'MedHHIncome_All', south_central_bounds)
average_income_la_county = tracts_income['MedHHIncome_All'].mean()

average_housing_costs_downtown = calculate_average_within_bounds(tracts_income, 'HousingCostPercentage', downtown_bounds)
average_housing_costs_south_central = calculate_average_within_bounds(tracts_income, 'HousingCostPercentage', south_central_bounds)
average_housing_costs_la_county = tracts_income['HousingCostPercentage'].mean()

# Create dataframes for plotting
income_data = pd.DataFrame({
    "Region": ["Downtown LA", "South Central LA", "Los Angeles County"],
    "Average Median Household Income": [
        average_income_downtown,
        average_income_south_central,
        average_income_la_county
    ]
})

housing_costs_data = pd.DataFrame({
    "Region": ["Downtown LA", "South Central LA", "Los Angeles County"],
    "Average Housing Costs as % of Income": [
        average_housing_costs_downtown,
        average_housing_costs_south_central,
        average_housing_costs_la_county
    ]
})

# Plot Average Median Household Income
plt.figure(figsize=(8, 6))
plt.bar(income_data["Region"], income_data["Average Median Household Income"], color=['#FF6347', '#FFA07A', '#FFE4B5'])
plt.title("Average Median Household Income by Region, 2024", fontsize=14)
plt.ylabel("Average Median Household Income ($)", fontsize=12)
plt.xlabel("Region", fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig('/home/jovyan/work/output/average_income_comparison.jpg', dpi=150)
plt.show()

# Plot Average Housing Costs as % of Income
plt.figure(figsize=(8, 6))
plt.bar(housing_costs_data["Region"], housing_costs_data["Average Housing Costs as % of Income"], color=['#4682B4', '#5F9EA0', '#B0C4DE'])
plt.title("Average Housing Costs as % of Income by Region, 2024", fontsize=14)
plt.ylabel("Average Housing Costs as % of Income (%)", fontsize=12)
plt.xlabel("Region", fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig('/home/jovyan/work/output/average_housing_costs_comparison.jpg', dpi=150)
plt.show()

# %% [markdown]
# ### Plotting live arrest data onto Average Median Income map

# %%
import pandas as pd
import plotly.express as px
from sodapy import Socrata

# %%
client = Socrata("data.lacity.org", None)
results = client.get("amvf-fr72", limit=2000) #get us the API unique identifier, from the URL or API endpoint
arrests = pd.DataFrame.from_records(results) #note that "results" is the variable input for the data
arrests.sample(2)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#        rpt_id report_type                arst_date  time area    area_desc  \
# 1127  6709785     BOOKING  2023-11-10T00:00:00.000  0205   09     Van Nuys
# 1815  6666571     BOOKING  2023-08-26T00:00:00.000  1200   12  77th Street
#
#         rd age sex_cd descent_cd chrg_grp_cd          grp_description  \
# 1127  0989  38      F          W          22  Driving Under Influence
# 1815  1233  18      M          H          07            Vehicle Theft
#
#      arst_typ_cd      charge                         chrg_desc  \
# 1127           M  23152(A)VC       DRUNK DRIVING ALCOHOL/DRUGS
# 1815           F  10851(A)VC  TAKE VEHICLE W/O OWNER'S CONSENT
#
#                        dispo_desc                         location      lat  \
# 1127                          NaN                          WOODMAN  34.1555
# 1815  MISDEMEANOR COMPLAINT FILED  59TH                         ST  33.9862
#
#             lon                                         location_1  \
# 1127  -118.4312  {'type': 'Point', 'coordinates': [-118.4312, 3...
# 1815  -118.3111  {'type': 'Point', 'coordinates': [-118.3111, 3...
#
#                      bkg_date bkg_time       bkg_location bkg_loc_cd  \
# 1127  2023-11-10T00:00:00.000     0309  VALLEY - JAIL DIV       4279
# 1815  2023-08-26T00:00:00.000     1429            77TH ST       4212
#
#      :@computed_region_qz3q_ghft :@computed_region_k96s_3jcv  \
# 1127                       19736                         331
# 1815                       23678                         769
#
#      :@computed_region_tatf_ua23 :@computed_region_ur2y_g4cx  \
# 1127                        1341                         NaN
# 1815                        1055                           7
#
#      :@computed_region_kqwf_mjcx :@computed_region_2dna_qi2s  \
# 1127                           7                          83
# 1815                          14                          35
#
#                                 crsst
# 1127  VENTURA                      FY
# 1815  ARLINGTON                    AV

# %%
from datetime import datetime
start_date = f"{datetime.now().year}-01-01T00:00:00"
end_date = datetime.now().strftime("%Y-%m-%dT%H:%M:%S")

# Get data from the API with live date range
results = client.get(
    "amvf-fr72", 
    limit=5000, 
    where=f"arst_date between '{start_date}' and '{end_date}'"
)

import pandas as pd
dfa = pd.DataFrame.from_records(results)

# Display the first few rows
print(dfa.head())
# Out:
#     rpt_id report_type                arst_date  time area    area_desc    rd  \
# 0  6945486     BOOKING  2025-01-01T00:00:00.000  2030   13       Newton  1371
# 1  6945475     BOOKING  2025-01-01T00:00:00.000  1825   10  West Valley  1025
# 2  6945170     BOOKING  2025-01-01T00:00:00.000  0735   06    Hollywood  0636
# 3  6945153     BOOKING  2025-01-01T00:00:00.000  0630   01      Central  0182
# 4  6945402     BOOKING  2025-01-01T00:00:00.000  0930   17   Devonshire  1794
#
#   age sex_cd descent_cd chrg_grp_cd                 grp_description  \
# 0  30      M          B          12             Weapon (carry/poss)
# 1  58      M          H          08                  Other Assaults
# 2  38      F          B          22         Driving Under Influence
# 3  29      M          B          24  Miscellaneous Other Violations
# 4  38      M          W          06                         Larceny
#
#   arst_typ_cd       charge                                   chrg_desc  \
# 0           F  25400(A)1PC           CARRY CONCEALED WEAPON IN VEHICLE
# 1           M  148(A)(1)PC                   OBSTRUCT/ETC PUB OFCR/ETC
# 2           M   23152(A)VC                 DRUNK DRIVING ALCOHOL/DRUGS
# 3           F   3455(B)1PC  WARRANT-PETITION TO REVOKE COMMUNITY SUPVN
# 4           M     484(A)PC                     GRAND THEFT (OVER $400)
#
#                     dispo_desc                                 location  \
# 0         CITY ATTORNEY REJECT                                 BROADWAY
# 1  MISDEMEANOR COMPLAINT FILED          SHERMAN                      WY
# 2  MISDEMEANOR COMPLAINT FILED                                   WILCOX
# 3                          NaN  1200 S  FLOWER                       ST
# 4  MISDEMEANOR COMPLAINT FILED          PARTHENIA                    ST
#
#                              crsst      lat        lon  \
# 0  52ND                         ST  33.9958  -118.2783
# 1                          LINDLEY  34.2011  -118.5273
# 2  HOLLYWOOD                    BL  34.1016   -118.331
# 3                              NaN  34.0415  -118.2655
# 4  LINDLEY                      ST  34.2287  -118.5273
#
#                                           location_1                 bkg_date  \
# 0  {'type': 'Point', 'coordinates': [-118.2783, 3...  2025-01-01T00:00:00.000
# 1  {'type': 'Point', 'coordinates': [-118.5273, 3...  2025-01-01T00:00:00.000
# 2  {'type': 'Point', 'coordinates': [-118.331, 34...  2025-01-01T00:00:00.000
# 3  {'type': 'Point', 'coordinates': [-118.2655, 3...  2025-01-01T00:00:00.000
# 4  {'type': 'Point', 'coordinates': [-118.5273, 3...  2025-01-01T00:00:00.000
#
#   bkg_time           bkg_location bkg_loc_cd
# 0     2245                77TH ST       4212
# 1     2204      VALLEY - JAIL DIV       4279
# 2     1057              HOLLYWOOD       4206
# 3     0909  METRO - JAIL DIVISION       4273
# 4     1340      VALLEY - JAIL DIV       4279

# %%
dfa.sample(5)
# Out:
#        rpt_id report_type                arst_date  time area    area_desc  \
# 2640  6957251     BOOKING  2025-01-24T00:00:00.000  1520   15  N Hollywood
# 647   6947510     BOOKING  2025-01-05T00:00:00.000  0900   05       Harbor
# 1634  6952535     BOOKING  2025-01-15T00:00:00.000  1930   10  West Valley
# 1501  6951353     BOOKING  2025-01-13T00:00:00.000  1740   01      Central
# 3140  6959240     BOOKING  2025-01-28T00:00:00.000  0845   07     Wilshire
#
#         rd age sex_cd descent_cd chrg_grp_cd                 grp_description  \
# 2640  1527  31      M          O          06                         Larceny
# 647   0529  46      M          H          24  Miscellaneous Other Violations
# 1634  1079  53      M          W          22         Driving Under Influence
# 1501  0195  35      M          H          07                   Vehicle Theft
# 3140  0743  33      M          W          05                        Burglary
#
#      arst_typ_cd      charge                         chrg_desc  \
# 2640           M  459.5(A)PC                       SHOPLIFTING
# 647            F    594(A)PC                         VANDALISM
# 1634           M  23152(F)VC                   DUI OF ANY DRUG
# 1501           F  10851(A)VC  TAKE VEHICLE W/O OWNER'S CONSENT
# 3140           F       459PC                          BURGLARY
#
#                        dispo_desc                                  location  \
# 2640  MISDEMEANOR COMPLAINT FILED  11000    VICTORY                      BL
# 647                           NaN           D                            ST
# 1634  MISDEMEANOR COMPLAINT FILED   4900    HASKELL                      AV
# 1501       FELONY COMPLAINT FILED           14TH                         ST
# 3140     DISTRICT ATTORNEY REJECT    800 S  FAIRFAX                      AV
#
#                                 crsst      lat        lon  \
# 2640                              NaN  34.1867  -118.3703
# 647   BROAD                        ST  33.7743  -118.2607
# 1634                              NaN  34.1594  -118.4749
# 1501  BROADWAY                     ST  34.0355  -118.2625
# 3140                              NaN   34.061  -118.3624
#
#                                              location_1  \
# 2640  {'type': 'Point', 'coordinates': [-118.3703, 3...
# 647   {'type': 'Point', 'coordinates': [-118.2607, 3...
# 1634  {'type': 'Point', 'coordinates': [-118.4749, 3...
# 1501  {'type': 'Point', 'coordinates': [-118.2625, 3...
# 3140  {'type': 'Point', 'coordinates': [-118.3624, 3...
#
#                      bkg_date bkg_time           bkg_location bkg_loc_cd
# 2640  2025-01-24T00:00:00.000     1654      VALLEY - JAIL DIV       4279
# 647   2025-01-05T00:00:00.000     2015                77TH ST       4212
# 1634  2025-01-15T00:00:00.000     2316      VALLEY - JAIL DIV       4279
# 1501  2025-01-13T00:00:00.000     1934  METRO - JAIL DIVISION       4273
# 3140  2025-01-28T00:00:00.000     1212  METRO - JAIL DIVISION       4273

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
from shapely.geometry import Point

# Step 1: Fetch live arrest data
from sodapy import Socrata
from datetime import datetime

client = Socrata("data.lacity.org", None)  

# Get live arrest data from Jan 1 to now
results = client.get(
    "amvf-fr72",
    limit=5000,
    where=f"arst_date between '{datetime.now().year}-01-01T00:00:00' and '{datetime.now().isoformat()}'"
)

# Convert to DataFrame
arrest_df = pd.DataFrame.from_records(results)

# Step 2: Prepare GeoDataFrame for arrest data
# Ensure latitude and longitude columns exist
arrest_df['latitude'] = arrest_df['lat'].astype(float)
arrest_df['longitude'] = arrest_df['lon'].astype(float)

# Create a GeoDataFrame
geometry = [Point(xy) for xy in zip(arrest_df['lon'], arrest_df['lat'])]
arrest_gdf = gpd.GeoDataFrame(arrest_df, geometry=geometry, crs="EPSG:4326")  # Use WGS84 CRS (common for GPS)

# Reproject to match income data CRS
arrest_gdf = arrest_gdf.to_crs(tracts_income.crs)

# Step 3: Plot income map with arrest data overlay
fig, ax = plt.subplots(figsize=(12, 12))

# Plot median income
tracts_income.plot(
    ax=ax,
    column='MedHHIncome_All',
    cmap='Reds',
    legend=True,
    alpha=0.7
)

# Overlay arrest points
arrest_gdf.plot(
    ax=ax,
    color='blue',
    markersize=10,
    alpha=0.5,
    label="Arrest Locations"
)

# Add labels and legend
ax.set_title('Median Income Map with Arrest Data (Live)', fontsize=16)
ax.legend(loc='lower right', fontsize=10)
ax.axis('off')

# Save and show plot
plt.savefig("income_arrest_map.jpg", dpi=150, bbox_inches='tight')
plt.show()
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
def isomap():    
    results = client.get(
        "amvf-fr72",
        limit=5000,
        where=f"arst_date between '{datetime.now().year}-01-01T00:00:00' and '{datetime.now().isoformat()}'"
    )
    
    # Convert to DataFrame
    arrest_df = pd.DataFrame.from_records(results)
    
    # Step 2: Prepare GeoDataFrame for arrest data
    # Ensure latitude and longitude columns exist
    arrest_df['latitude'] = arrest_df['lat'].astype(float)
    arrest_df['longitude'] = arrest_df['lon'].astype(float)
    
    # Create a GeoDataFrame
    geometry = [Point(xy) for xy in zip(arrest_df['lon'], arrest_df['lat'])]
    arrest_gdf = gpd.GeoDataFrame(arrest_df, geometry=geometry, crs="EPSG:4326")  # Use WGS84 CRS (common for GPS)
    
    # Reproject to match income data CRS
    arrest_gdf = arrest_gdf.to_crs(tracts_income.crs)
    
    # Step 3: Plot income map with arrest data overlay
    fig, ax = plt.subplots(figsize=(12, 12))
    
    # Plot median income
    tracts_income.plot(
        ax=ax,
        column='HousingCostPercentage',
        cmap='Reds',
        legend=True,
        alpha=0.7
    )
    
    # Overlay arrest points
    arrest_gdf.plot(
        ax=ax,
        color='blue',
        markersize=10,
        alpha=0.5,
        label="Arrest Locations"
    )
    
    # Add labels and legend
    ax.set_title('Housing Costs as a Percentage of Income with Arrest Data (Live)', fontsize=16)
    ax.legend(loc='lower right', fontsize=10)
    ax.axis('off')
    
    # Save and show plot
    plt.savefig("housing_costs_arrest_map.jpg", dpi=150, bbox_inches='tight')
    plt.show()

# %%
isomap()

# %%
locations = {
    "Downtown LA": {
        "min_lat": 34.03, "max_lat": 34.06,
        "min_lon": -118.27, "max_lon": -118.23
    },
    "South Central LA": {
        "min_lat": 33.96, "max_lat": 34.02,
        "min_lon": -118.30, "max_lon": -118.26
    }
}

def isomap(location_name, min_lat, max_lat, min_lon, max_lon):
    print(f"Generating map for {location_name}...")

    # Step 1: Fetch arrest data within the location and date range
    where_clause = (
        f"arst_date between '{datetime.now().year}-01-01T00:00:00' and '{datetime.now().isoformat()}' "
        f"AND lat BETWEEN {min_lat} AND {max_lat} "
        f"AND lon BETWEEN {min_lon} AND {max_lon}"
    )
    
    results = client.get("amvf-fr72", limit=5000, where=where_clause)
    
    # Convert to DataFrame
    arrest_df = pd.DataFrame.from_records(results)

    # Ensure lat/lon exist
    if 'lat' not in arrest_df or 'lon' not in arrest_df:
        print(f"No data available for {location_name}. Skipping...")
        return
    
    # Convert to float
    arrest_df['latitude'] = arrest_df['lat'].astype(float)
    arrest_df['longitude'] = arrest_df['lon'].astype(float)

    # Create GeoDataFrame
    geometry = [Point(xy) for xy in zip(arrest_df['longitude'], arrest_df['latitude'])]
    arrest_gdf = gpd.GeoDataFrame(arrest_df, geometry=geometry, crs="EPSG:4326")

    # Reproject to match income data CRS
    arrest_gdf = arrest_gdf.to_crs(tracts_income.crs)

    # Step 3: Plot
    fig, ax = plt.subplots(figsize=(12, 12))

    # Plot median income data
    tracts_income.plot(ax=ax, column='HousingCostPercentage', cmap='Reds', legend=True, alpha=0.7)

    # Overlay arrests
    arrest_gdf.plot(ax=ax, color='blue', markersize=10, alpha=0.5, label="Arrest Locations")

    # Add labels and legend
    ax.set_title(f'Housing Costs & Arrests in {location_name}', fontsize=16)
    ax.legend(loc='lower right', fontsize=10)
    ax.axis('off')

    # Save and show plot
    plt.savefig(f"{location_name.replace(' ', '_').lower()}_map.jpg", dpi=150, bbox_inches='tight')
    plt.show()


# **Loop through locations and generate maps**
for name, bounds in locations.items():
    isomap(name, **bounds)
# Out:
# Generating map for Downtown LA...
# Generating map for South Central LA...

# %%
locations = {
    "Downtown LA": {
        "min_lat": 34.03, "max_lat": 34.06,
        "min_lon": -118.27, "max_lon": -118.23
    },
    "South Central LA": {
        "min_lat": 33.96, "max_lat": 34.02,
        "min_lon": -118.30, "max_lon": -118.26
    }
}

def isomap(location_name, min_lat, max_lat, min_lon, max_lon):
    print(f"Generating map for {location_name}...")

    # Step 1: Fetch arrest data within the location and date range
    where_clause = (
        f"arst_date between '{datetime.now().year}-01-01T00:00:00' and '{datetime.now().isoformat()}' "
        f"AND lat BETWEEN {min_lat} AND {max_lat} "
        f"AND lon BETWEEN {min_lon} AND {max_lon}"
    )
    
    results = client.get("amvf-fr72", limit=5000, where=where_clause)
    
    # Convert to DataFrame
    arrest_df = pd.DataFrame.from_records(results)

    # Ensure lat/lon exist
    if 'lat' not in arrest_df or 'lon' not in arrest_df:
        print(f"No data available for {location_name}. Skipping...")
        return
    
    # Convert to float
    arrest_df['latitude'] = arrest_df['lat'].astype(float)
    arrest_df['longitude'] = arrest_df['lon'].astype(float)

    # Create GeoDataFrame
    geometry = [Point(xy) for xy in zip(arrest_df['longitude'], arrest_df['latitude'])]
    arrest_gdf = gpd.GeoDataFrame(arrest_df, geometry=geometry, crs="EPSG:4326")

    # Reproject to match income data CRS
    arrest_gdf = arrest_gdf.to_crs(tracts_income.crs)

    # Step 2: Filter income data to match location
    tracts_income_filtered = tracts_income.cx[min_lon:max_lon, min_lat:max_lat]

    # Step 3: Plot
    fig, ax = plt.subplots(figsize=(10, 10))

    # Plot median income data (only for the given area)
    tracts_income_filtered.plot(ax=ax, column='HousingCostPercentage', cmap='Reds', legend=True, alpha=0.7)

    # Overlay arrests
    arrest_gdf.plot(ax=ax, color='blue', markersize=10, alpha=0.5, label="Arrest Locations")

    # Set zoomed-in view
    ax.set_xlim(min_lon, max_lon)
    ax.set_ylim(min_lat, max_lat)

    # Add labels and legend
    ax.set_title(f'Housing Costs & Arrests in {location_name}', fontsize=16)
    ax.legend(loc='lower right', fontsize=10)
    ax.axis('off')

    # Save and show plot
    plt.savefig(f"{location_name.replace(' ', '_').lower()}_zoomed_map.jpg", dpi=150, bbox_inches='tight')
    plt.show()


# **Loop through locations and generate zoomed-in maps**
for name, bounds in locations.items():
    isomap(name, **bounds)
# Out:
# Generating map for Downtown LA...
# Generating map for South Central LA...

# %%
import math
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point

from geopy.distance import great_circle

def isomap(location_name, center_lat, center_lon, radius_miles):
    print(f"Generating map for {location_name} within {radius_miles} miles...")

    # Convert miles to degrees (approximate conversion)
    lat_buffer = radius_miles / 69  # 1 degree latitude ≈ 69 miles
    lon_buffer = radius_miles / (69 * abs(math.cos(math.radians(center_lat))))  # Adjust for longitude shrinking toward poles

    # Define bounding box
    min_lat, max_lat = center_lat - lat_buffer, center_lat + lat_buffer
    min_lon, max_lon = center_lon - lon_buffer, center_lon + lon_buffer

    # Step 1: Fetch arrest data within the location and date range
    where_clause = (
        f"arst_date between '{datetime.now().year}-01-01T00:00:00' and '{datetime.now().isoformat()}' "
        f"AND lat BETWEEN {min_lat} AND {max_lat} "
        f"AND lon BETWEEN {min_lon} AND {max_lon}"
    )
    
    results = client.get("amvf-fr72", limit=5000, where=where_clause)
    
    # Convert to DataFrame
    arrest_df = pd.DataFrame.from_records(results)

    # Ensure lat/lon exist
    if 'lat' not in arrest_df or 'lon' not in arrest_df:
        print(f"No data available for {location_name}. Skipping...")
        return
    
    # Convert to float
    arrest_df['latitude'] = arrest_df['lat'].astype(float)
    arrest_df['longitude'] = arrest_df['lon'].astype(float)

    # Create GeoDataFrame
    geometry = [Point(xy) for xy in zip(arrest_df['longitude'], arrest_df['latitude'])]
    arrest_gdf = gpd.GeoDataFrame(arrest_df, geometry=geometry, crs="EPSG:4326")

    # Reproject to match income data CRS
    arrest_gdf = arrest_gdf.to_crs(tracts_income.crs)

    # Step 2: Filter income data to match location
    tracts_income_filtered = tracts_income.cx[min_lon:max_lon, min_lat:max_lat]

    # Step 3: Plot
    fig, ax = plt.subplots(figsize=(10, 10))

    # Plot median income data (only for the given area)
    tracts_income_filtered.plot(ax=ax, column='HousingCostPercentage', cmap='Reds', legend=True, alpha=0.7)

    # Overlay arrests
    arrest_gdf.plot(ax=ax, color='blue', markersize=10, alpha=0.5, label="Arrest Locations")

    # Set zoomed-in view
    ax.set_xlim(min_lon, max_lon)
    ax.set_ylim(min_lat, max_lat)

    # Add labels and legend
    ax.set_title(f'Housing Costs & Arrests in {location_name}', fontsize=16)
    ax.legend(loc='lower right', fontsize=10)
    ax.axis('off')

    # Save and show plot
    plt.savefig(f"{location_name.replace(' ', '_').lower()}_{radius_miles}mi_zoomed_map.jpg", dpi=150, bbox_inches='tight')
    plt.show()

# %%
#Downtown: Downtown Los Angeles (DTLA): Latitude: 34.0407 Longitude: -118.2468
#South Central:South Central Los Angeles: Latitude: 34.0006 Longitude: -118.2816
# Define locations with center coordinates and radius
locations = {
    "Downtown LA": {"lat": 34.0407, "lon": -118.2468, "radius": 5},
    "South Central LA": {"lat": 34.0006, "lon": -118.2816, "radius": 5}
}

# Loop through locations and generate maps
for name, info in locations.items():
    isomap(name, info["lat"], info["lon"], info["radius"])
# Out:
# Generating map for Downtown LA within 5 miles...
# Generating map for South Central LA within 5 miles...

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns
from shapely.geometry import Point
from scipy.stats import spearmanr

def spatial_correlation():
    # Get latest arrest data
    results = client.get(
        "amvf-fr72",
        limit=5000,
        where=f"arst_date between '{datetime.now().year}-01-01T00:00:00' and '{datetime.now().isoformat()}'"
    )
    
    # Convert to DataFrame
    arrest_df = pd.DataFrame.from_records(results)

    # Ensure numeric lat/lon
    arrest_df['latitude'] = arrest_df['lat'].astype(float)
    arrest_df['longitude'] = arrest_df['lon'].astype(float)

    # Convert to GeoDataFrame
    geometry = [Point(xy) for xy in zip(arrest_df['lon'], arrest_df['lat'])]
    arrest_gdf = gpd.GeoDataFrame(arrest_df, geometry=geometry, crs="EPSG:4326")
    
    # Reproject to match tracts
    arrest_gdf = arrest_gdf.to_crs(tracts_income.crs)

    # **1. Spatial Join**: Assign each arrest to a census tract
    joined = gpd.sjoin(arrest_gdf, tracts_income, how="left", predicate="within")

    # **2. Count arrests per tract**
    arrest_counts = joined.groupby("HousingCostPercentage").size().reset_index(name="arrest_count")

    # **3. Merge with tracts_income data**
    tracts_income_counts = tracts_income.merge(arrest_counts, on="HousingCostPercentage", how="left")
    tracts_income_counts["arrest_count"] = tracts_income_counts["arrest_count"].fillna(0)  # Fill missing with 0

    # **4. Compute Correlation**
    corr, p_value = spearmanr(
        tracts_income_counts["HousingCostPercentage"], 
        tracts_income_counts["arrest_count"]
    )

    print(f"Spearman Correlation: {corr:.4f} (p-value: {p_value:.4f})")

    # **5. Scatterplot of Housing Cost % vs Arrest Count**
    plt.figure(figsize=(8, 6))
    sns.scatterplot(
        x=tracts_income_counts["HousingCostPercentage"],
        y=tracts_income_counts["arrest_count"],
        alpha=0.6
    )
    plt.xlabel("Housing Cost as % of Income")
    plt.ylabel("Arrest Count")
    plt.title(f"Spatial Correlation: Arrests vs Housing Cost % (Spearman: {corr:.2f})")
    plt.show()
    
    # **6. Choropleth Map of Arrest Density**
    fig, ax = plt.subplots(figsize=(12, 12))
    tracts_income_counts.plot(
        ax=ax, column="arrest_count", cmap="Blues", legend=True, alpha=0.7
    )
    ax.set_title("Arrests per Census Tract", fontsize=16)
    ax.axis('off')
    plt.show()

spatial_correlation()
# Out:
# Spearman Correlation: nan (p-value: nan)
